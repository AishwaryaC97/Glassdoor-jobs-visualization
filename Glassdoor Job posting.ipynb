# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
glassdoor_data=pd.read_csv("C:/Users/Aishu/Desktop/glassdoor job posting.csv")

# %%
glassdoor_data.head()
# Out:
#                                     Job Title  Salary Estimate  \
# 0             Big Data & Analytics Consultant               -1
# 1               Data Scientist - QuantumBlack               -1
# 2                  IT Security Data Scientist               -1
# 3  Data Scientist - Risk Modelling Specialist               -1
# 4                              Data Scientist               -1
#
#                                      Job Description  Rating  \
# 0  Are you passionate about analytics? Would you ...     3.9
# 1  QUALIFICATIONS\nBachelor or Masters or PhD lev...     4.4
# 2  Job Title:\nIT Security Data Scientist\n\nJob ...     3.9
# 3  Company Description\n\nCermati is a financial ...     4.4
# 4  HappyFresh is Southeast Asia's #1 Online Groce...     4.3
#
#               Company Name Location                  Size  Founded  \
# 0              Amazon\n3.9  Jakarta      10000+ Employees     1994
# 1  McKinsey & Company\n4.4  Jakarta      10000+ Employees     1926
# ...

# %%
#sns.barplot(x='Founded',y='Company Name',data=glassdoor_data)

# %%
sns.heatmap(glassdoor_data.corr())

# %%
glassdoor_data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue'],
#       dtype='object')

# %%
glassdoor_data.drop(['Salary Estimate'], axis = 1, inplace = True)
#dropping this table since it has white space

# %%
glassdoor_data.rename({'Job Title':'job_title', 
             'Job Description':'job_desc', 
             'Rating':'rating',
             'Company Name':'company name', 
             'Location':'location', 
             'Size':'size', 
             'Founded':'founded', 
             'Type of ownership':'type_of_ownership',
             'Industry':'industry', 
             'Sector':'sector', 
             'Revenue':'revenue'},axis = 1, inplace = True)

# %%
plt.figure(figsize=(10,7))
glassdoor_data['job_title'].value_counts().head(10).plot.bar()

# %%
#replacing -1 with nan value

# %%
glassdoor_data.replace(-1,np.nan,inplace = True)
glassdoor_data.replace('-1',np.nan,inplace = True)

# %%
plt.figure(figsize=(9,6))
glassdoor_data['sector'].value_counts().plot.pie()

# %%
#topjob location
plt.figure(figsize=(9,6))
#glassdoor_data['location'].value_counts().plot.hist()
glassdoor_data['location'].value_counts().plot.bar()
